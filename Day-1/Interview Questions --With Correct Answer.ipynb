# %% [markdown]
# 1️⃣ What is Python?
#
# Python is a high-level, interpreted, object-oriented programming language used for web development, automation, AI, data science, and software development.
# It focuses on readability & simplicity.

# %% [markdown]
# 2️⃣ What is a variable?
#
# A variable is a name that stores a value in memory.
#
# Example:
#
# x = 10

# %% [markdown]
# 3️⃣ Difference between variable & data type?
# Variable	Data Type
# Name used to store value in memory	Type of value stored
# age = 21	21 → integer

# %% [markdown]
# 4️⃣ What is input() & print()?
# Function	Use
# input()	Takes input from user
# print()	Displays output on screen

# %% [markdown]
# 5️⃣ What is type()?
#
# It returns data type of a variable.
#
# Example:
#
# x = 10
# print(type(x))   # <class 'int'>

# %% [markdown]
# What are comments?
#
# Comments explain code.
# Python ignores them during execution.
#
# # single line comment
# """
# multi line comment

# %% [markdown]
# Mutable vs Immutable?
# Mutable (can change)	Immutable (cannot change)
# List	                  int
# Dictionary	              float
# Set	                      string
# tuple

# %% [markdown]
# 8️⃣ What is a generator?
#
# Generator gives values one at a time using yield (memory efficient).
#
# def gen():
#     for i in range(3):
#         yield i
#
# for x in gen():
#     print(x)

# %% [markdown]
# 9️⃣ What is GIL?
#
# GIL = Global Interpreter Lock
# It allows one thread to run Python byte-code at a time.
# Python's threading isn't true parallelism for CPU tasks.

# %% [markdown]
# 🔟 What is a virtual environment?
#
# A separate environment to install project-specific Python packages without affecting system Python.
