# %%
#✅ Write JSON 

import json 

data = {"name": "Divyanshu","age":23}

with open ("data.json","w") as f:
    json.dump(data, f , indent = 4)

# %%
#✅ Read JSON 

import json 

with open("data.json","r") as f:
    data = json.load(f) 
    print(data)
# Out:
# {'name': 'Divyanshu', 'age': 23}
