# %% [markdown]
# 📌 A. Strings
#
# ✔ Palindrome
# ✔ Reverse
# ✔ Frequency count
# ✔ Removing duplicates

# %%
def is_palindrome(s):
    return s == s[::-1]

# %% [markdown]
# 📌 B. Searching / Sorting
#
# ✔ Linear search
# ✔ Binary search
# ✔ Bubble, Selection, Insertion, Quick sort

# %% [markdown]
# 📌 C. Stack + Queue
#
# ✔ Balanced parentheses
# ✔ Next greater element
# ✔ Queue with 2 stacks

# %% [markdown]
# 📌 D. Linked List
#
# ✔ Node
# ✔ Insert
# ✔ Delete
# ✔ Search
# ✔ Count nodes

# %% [markdown]
# 📌 E. Recursion
#
# ✔ Factorial
# ✔ Fibonacci
# ✔ Sum of digits
# ✔ Power function
