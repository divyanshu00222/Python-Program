# %%
#✅ 1️⃣ Class Variables vs Instance Variables 

class Student:
    school = "ABC School"   # class variable

    def __init__(self, name):
        self.name = name    # instance variable

s1 = Student("Divyanshu")
s2 = Student("Rahul")

print(s1.school)
print(s2.school)
# Out:
# ABC School
# ABC School

# %%
#✅ 2️⃣ Static Methods 

class Math:
    @staticmethod 
    def add(a,b):
        return a+b 
    
print(Math.add(10,20))
# Out:
# 30

# %%
# ✅ 3️⃣ Class Methods

# Works with class variables. 

class Student:
    count = 0

    def __init__(self):
        self.name = name 
        Student.count += 1

    @classmethod
    def total_student(cls):
        return cls.count 
    
print(Student.total_student())
# Out:
# 0

# %%
# ✅ 4️⃣ Multiple Inheritance 
class Father:
    def work(self) : return "Business" 

class Mother:
    def skills(self): return "Cooking" 

class child(Father,Mother):
    pass 

c = child() 
print(c.work(),c.skills())
# Out:
# Business Cooking

# %%
#✅ 5️⃣ Super() Keyword 

class A:
    def show(self):
        print("A method") 

class B(A):
    def show(self):
        super().show()
        print("B method") 
    
B().show()
# Out:
# A method
# B method
