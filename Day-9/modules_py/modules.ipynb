# %%
#✅ math_ops.py 

def add(a,b):
    return a+b 

def sub(a,b):
    return a-b

# %%
# main.py 

import math_ops

print(math_ops.add(5, 3))
print(math_ops.sub(10, 4))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # main.py
# ----> 3 import math_ops
#       5 print(math_ops.add(5, 3))
#       6 print(math_ops.sub(10, 4))
#
# ModuleNotFoundError: No module named 'math_ops'
