# %%
#1️⃣ Find the index of first and last occurrence of an element 
def first_last(arr, x):
    first = last = -1
    for i in range(len(arr)):
        if arr[i] == x:
            if first == -1:
                first = i
            last = i
    return first, last

print(first_last([1, 2, 2, 2, 3, 4], 2))  # Output: (1, 3)

# %%
#2️⃣ Count occurrences of an element in sorted array 

def count_occurrences(arr, x):
    return arr.count(x)

print(count_occurrences([1, 2, 2, 2, 3, 4], 2))  # Output: 3

# %%
#3️⃣ Find element in rotated sorted array 
def search_rotated(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        if arr[low] <= arr[mid]:
            if arr[low] <= target < arr[mid]:
                high = mid - 1
            else:
                low = mid + 1
        else:
            if arr[mid] < target <= arr[high]:
                low = mid + 1
            else:
                high = mid - 1
    return -1

print(search_rotated([4,5,6,7,0,1,2], 0))  # Output: 4

# %%
#4️⃣ Find square root using Binary Search 
def sqrt_binary_search(n):
    low, high = 0, n
    ans = 0
    while low <= high:
        mid = (low + high) // 2
        if mid * mid == n:
            return mid
        if mid * mid < n:
            low = mid + 1
            ans = mid
        else:
            high = mid - 1
    return ans

print(sqrt_binary_search(37))  # Output: 6

# %%
#5️⃣ Peak Element in an array 
def find_peak(arr):
    low, high = 0, len(arr) - 1
    while low < high:
        mid = (low + high) // 2
        if arr[mid] < arr[mid + 1]:
            low = mid + 1
        else:
            high = mid
    return arr[low]

print(find_peak([1, 3, 20, 4, 1, 0]))  # Output: 20
