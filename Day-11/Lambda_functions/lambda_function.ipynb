# %%
#✅ Basic Example 

add = lambda a,b : a+ b
print(add(5,3))
# Out:
# 8

# %%
#✅ Square all numbers 

nums = [1,2,3,4]
squares = list(map(lambda x: x*x, nums)) 
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
#✅ Sort list of tuples 

data = [(1,4),(2,1),(3,3)]
data.sort(key=lambda x: x[1]) 
print(data)
# Out:
# [(2, 1), (3, 3), (1, 4)]
