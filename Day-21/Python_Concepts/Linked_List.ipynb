# %% [markdown]
# 🧩 1️⃣ What is a Linked List?
#
# A Linked List is a linear data structure where elements are connected using pointers (nodes).
# Each node contains:
#
# data → the value
#
# next → a reference (address) to the next node

# %% [markdown]
# 🧱 Types of Linked Lists
#
# Singly Linked List – One direction (A → B → C)
#
# Doubly Linked List – Two directions (A ↔ B ↔ C)
#
# Circular Linked List – Last node points to the first
