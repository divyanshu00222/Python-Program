# %%
#Function to find square of numbers
def square(n):
    return n * n 
print(square(5))
# Out:
# 25

# %%
#Function to check even or odd
def check_even(n):
    if n % 2 == 0:
        return "Even"
    else :
        return "Odd"
    
print(check_even(7))
# Out:
# Odd
