# %% [markdown]
# 📌 2️⃣ QUEUE (FIFO – First In First Out)
#
# Real life example → Waiting lines, CPU scheduling, Printers

# %%
#✔ Queue using deque 

from collections import deque

q = deque()

q.append(10)
q.append(20)
q.append(30)

print(q.popleft())   # 10
print(q[0])          # front → 20
